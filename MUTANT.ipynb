# %%
# !git clone https://github.com/Coac-syf/MUTANT.git

# %%
# %cd MUTANT

# %%
# !cp -r ../data/SMAP/ ./processed/

# %%
### Before training and testing, please change the necessary parameters in the MUTANT/main.py and MUTANT/utils.py files.
# !python main.py
